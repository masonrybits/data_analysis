# %% [markdown]
# # Analysis on relationship between chance of admit and GRE score

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
admission = pd.read_csv("./Admission_Predict_Ver1.1.csv")
print(f"Data Shape: {admission.shape}")
print(admission.head())
print(admission.info())
# Out:
# Data Shape: (500, 9)
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
# Serial No.           500 non-null int64
# GRE Score            500 non-null int64
# TOEFL Score          500 non-null int64
# University Rating    500 non-null int64
# SOP                  500 non-null float64
# ...

# %%
X = admission['GRE Score'].values
y = admission['Chance of Admit '].values

# %%
X=X.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y,train_size=0.8,test_size=0.2,random_state=100)
print(f"X_train shape {x_train.shape}")
print(f"y_train shape {y_train.shape}")
print(f"X_test shap {x_test.shape}")
print(f"y_test shape {y_test.shape}")
print(y_test)
# Out:
# X_train shape (400, 1)
# y_train shape (400,)
# X_test shap (100, 1)
# y_test shape (100,)
# [0.78 0.54 0.64 0.47 0.7  0.88 0.57 0.72 0.84 0.64 0.79 0.56 0.92 0.79
#  0.73 0.52 0.62 0.81 0.57 0.65 0.93 0.65 0.86 0.87 0.97 0.65 0.57 0.95
#  0.91 0.74 0.85 0.81 0.73 0.39 0.8  0.79 0.73 0.65 0.58 0.75 0.94 0.71
#  0.86 0.78 0.87 0.56 0.62 0.95 0.93 0.62 0.81 0.74 0.84 0.96 0.46 0.88
#  0.64 0.9  0.78 0.71 0.64 0.73 0.47 0.93 0.75 0.68 0.78 0.34 0.83 0.9
#  0.94 0.73 0.71 0.87 0.64 0.79 0.59 0.7  0.95 0.92 0.64 0.65 0.91 0.73
#  0.91 0.76 0.54 0.68 0.76 0.68 0.72 0.67 0.67 0.94 0.93 0.77 0.86 0.8
#  0.64 0.84]

# %%
# %matplotlib inline
plt.scatter(x_train,y_train,color='green')
plt.xlabel('Chance of Admit')
plt.ylabel('GRE Score')
plt.title('relationship between chance of admit and GRE score')
plt.show()

# %%
lm = LinearRegression()
lm.fit(x_train,y_train)
y_predict = lm.predict(x_test)
print(f"Train accuracy {round(lm.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lm.score(x_test,y_test)*100,2)} %")
# Out:
# Train accuracy 65.22 %
# Test accuracy 66.17 %

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,y_predict)
plt.xlabel('Chance of Admit')
plt.ylabel('GRE Score')
plt.title('relationship between chance of admit and GRE score')
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %% [markdown]
# ## Conclusions

# %% [markdown]
# * GRE score is positively correlated to the chace of admit.
# * The accuracy for train and test are both around 65%, which can be improved.
# * We want to add more independent variables such as GPA to have a better prediction of chance of admit.
